# %%
# !pip install higher scikit-learn
# Out:
# Requirement already satisfied: higher in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from higher) (2.10.0+cu128)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->higher) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->higher) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->higher) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->higher) (1.4.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->higher) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->higher) (3.0.3)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchvision.models as models
import torchvision.datasets as datasets
from torch.utils.data import Dataset
import numpy as np
import random
from sklearn.metrics import f1_score, accuracy_score
import higher

# %%
# =========================
# 2. TRANSFORMS
# =========================
transform_train = transforms.Compose([
    transforms.Resize((256,256)),
    transforms.RandomResizedCrop(224, scale=(0.6,1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(p=0.2),
    transforms.RandomRotation(15),
    transforms.ColorJitter(0.4,0.4,0.4,0.1),
    transforms.RandomGrayscale(p=0.1),
    transforms.GaussianBlur(3),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])

# %%
transform_test = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])

# %%
# =========================
# 3. DEVICE
# =========================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# !wget -O dataset.zip "https://data.mendeley.com/public-files/datasets/tywbtsjrjv/files/b4e3a32f-c0bd-4060-81e9-6144231f2520/file_downloaded" && unzip dataset.zip

#plantDoc Dataset
# !git clone https://github.com/pratikkayal/PlantDoc-Dataset.git
# Out:
# Device: cuda
# --2026-03-26 08:26:53--  https://data.mendeley.com/public-files/datasets/tywbtsjrjv/files/b4e3a32f-c0bd-4060-81e9-6144231f2520/file_downloaded
# Resolving data.mendeley.com (data.mendeley.com)... 162.159.133.86, 162.159.130.86
# Connecting to data.mendeley.com (data.mendeley.com)|162.159.133.86|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com/349ac012-2948-4172-bbba-3bf8f76596fd [following]
# --2026-03-26 08:26:53--  https://prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com/349ac012-2948-4172-bbba-3bf8f76596fd
# Resolving prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com (prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com)... 52.92.0.122, 3.5.72.104, 3.5.75.61, ...
# Connecting to prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com (prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com)|52.92.0.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 949267727 (905M) [application/zip]
# Saving to: ‘dataset.zip’
#
# dataset.zip         100%[===================>] 905.29M  9.96MB/s    in 47s
#
# 2026-03-26 08:27:41 (19.1 MB/s) - ‘dataset.zip’ saved [949267727/949267727]
#
# Archive:  dataset.zip
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (1).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (1).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (10).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (10).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (100).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (100).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (1000).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (1000).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (101).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (101).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (102).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (102).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (103).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (103).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (104).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (104).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (105).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (105).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (106).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (106).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (107).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (107).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (108).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (108).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (109).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (109).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (11).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (11).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (110).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (110).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (111).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (111).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (112).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (112).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (113).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (113).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (114).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (114).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (115).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (115).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (116).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (116).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (117).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (117).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (118).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (118).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (119).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (119).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (12).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (12).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (120).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (120).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (121).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (121).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (122).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (122).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (123).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (123).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (124).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (124).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (125).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (125).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (126).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (126).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (127).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (127).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (128).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (128).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (129).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (129).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (13).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (13).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (130).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (130).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (131).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (131).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (132).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (132).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (133).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (133).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (134).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (134).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (135).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (135).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (136).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (136).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (137).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (137).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (138).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (138).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (139).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (139).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (14).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (14).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (140).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (140).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (141).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (141).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (142).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (142).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (143).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (143).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (144).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (144).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (145).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (145).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (146).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (146).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (147).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (147).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (148).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (148).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (149).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (149).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (15).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (15).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (150).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (150).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (151).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (151).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (152).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (152).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (153).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (153).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (154).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (154).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (155).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (155).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (156).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (156).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (157).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (157).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (158).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (158).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (159).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (159).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (16).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (16).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (160).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (160).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (161).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (161).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (162).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (162).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (163).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (163).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (164).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (164).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (165).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (165).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (166).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (166).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (167).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (167).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (168).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (168).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (169).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (169).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (17).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (17).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (170).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (170).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (171).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (171).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (172).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (172).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (173).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (173).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (174).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (174).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (175).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (175).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (176).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (176).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (177).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (177).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (178).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (178).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (179).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (179).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (18).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (18).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (180).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (180).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (181).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (181).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (182).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (182).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (183).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (183).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (184).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (184).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (185).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (185).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (186).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (186).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (187).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (187).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (188).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (188).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (189).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (189).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (19).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (19).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (190).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (190).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (191).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (191).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (192).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (192).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (193).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (193).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (194).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (194).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (195).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (195).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (196).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (196).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (197).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (197).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (198).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (198).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (199).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (199).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (2).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (2).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (20).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (20).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (200).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (200).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (201).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (201).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (202).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (202).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (203).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (203).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (204).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (204).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (205).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (205).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (206).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (206).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (207).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (207).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (208).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (208).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (209).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (209).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (21).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (21).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (210).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (210).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (211).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (211).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (212).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (212).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (213).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (213).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (214).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (214).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (215).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (215).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (216).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (216).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (217).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (217).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (218).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (218).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (219).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: yy
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (219).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (22).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (22).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (220).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (220).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (221).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (221).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (222).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (222).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (223).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (223).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (224).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (224).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (225).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (225).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (226).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (226).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (227).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (227).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (228).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (228).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (229).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (229).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (23).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (23).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (230).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (230).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (231).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (231).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (232).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (232).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (233).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (233).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (234).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (234).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (235).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (235).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (236).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (236).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (237).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (237).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (238).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (238).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (239).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (239).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (24).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (24).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (240).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (240).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (241).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (241).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (242).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (242).JPG
# replace Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (243).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
plantvillage = datasets.ImageFolder(
    "/content/Plant_leave_diseases_dataset_with_augmentation",
    transform=transform_train
)

plantdoc = datasets.ImageFolder(
    "/content/PlantDoc-Dataset/train",
    transform=transform_train
)

print("PlantVillage:", len(plantvillage))
print("PlantDoc:", len(plantdoc))
# Out:
# PlantVillage: 61486
# PlantDoc: 2342

# %%
class CombinedDataset(Dataset):
    def __init__(self, d1, d2):
        self.d1 = d1
        self.d2 = d2

    def __len__(self):
        return len(self.d1) + len(self.d2)

    def __getitem__(self, idx):
        if idx < len(self.d1):
            img,label = self.d1[idx]
            return img,label,0
        else:
            img,label = self.d2[idx-len(self.d1)]
            return img,label,1

combined_dataset = CombinedDataset(plantdoc, plantvillage)

# %%
class EfficientNetEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        base = models.efficientnet_b0(weights="DEFAULT")
        self.backbone = base.features
        self.pool = nn.AdaptiveAvgPool2d((1,1))
        self.fc = nn.Linear(1280,128)

    def forward(self,x):
        x = self.backbone(x)
        x = self.pool(x)
        x = x.view(x.size(0),-1)
        return self.fc(x)

# %%
# =========================
# 7. LOSSES
# =========================
class SupConLoss(nn.Module):
    def __init__(self,temp=0.07):
        super().__init__()
        self.temp=temp

    def forward(self,f,l):
        f = F.normalize(f,dim=1)
        sim = torch.matmul(f,f.T)/self.temp

        l = l.unsqueeze(1)
        mask = torch.eq(l,l.T).float().to(f.device)

        logits_mask = torch.ones_like(mask) - torch.eye(mask.shape[0]).to(f.device)
        mask = mask * logits_mask

        exp = torch.exp(sim) * logits_mask
        log_prob = sim - torch.log(exp.sum(1,keepdim=True))

        return -(mask * log_prob).sum(1).mean()

def compute_prototypes(features, labels, n_way):
    return torch.stack([
        features[labels==c].mean(0) for c in range(n_way)
    ])

def domain_loss(features, labels, domains, n_way):

    loss = 0
    count = 0

    for c in range(n_way):
        src = features[(labels==c) & (domains==0)]
        tgt = features[(labels==c) & (domains==1)]

        if len(src)>0 and len(tgt)>0:
            loss += F.mse_loss(src.mean(0), tgt.mean(0))
            count += 1

    if count == 0:
        return torch.tensor(0.0).to(features.device)

    return loss / count

# %%
# =========================
# 8. DISTANCE FUNCTION (FIXED)
# =========================
def euclidean_dist(x, y):
    n = x.size(0)
    m = y.size(0)

    x = x.unsqueeze(1).expand(n, m, -1)
    y = y.unsqueeze(0).expand(n, m, -1)

    return ((x - y) ** 2).sum(2)

# %%
# =========================
# 9. SAMPLER (FAST)
# =========================
class Sampler:
    def __init__(self,dataset,n_way=5,k=5,q=10,episodes=1000):
        self.dataset = dataset
        self.n_way=n_way
        self.k=k
        self.q=q
        self.episodes=episodes

        self.class_idx={}
        for i, label in enumerate(dataset.targets):
            self.class_idx.setdefault(label,[]).append(i)

        self.classes=list(self.class_idx.keys())

    def __iter__(self):
        for _ in range(self.episodes):
            cls=random.sample(self.classes,self.n_way)

            s_idx,q_idx=[],[]

            for c in cls:
                idx=random.sample(self.class_idx[c],self.k+self.q)
                s_idx+=idx[:self.k]
                q_idx+=idx[self.k:]

            yield s_idx,q_idx,cls

# %%
def create_episode_reverse(dataset, s_idx, q_idx, classes):

    cmap = {c:i for i,c in enumerate(classes)}

    sx, sy, sd = [], [], []
    qx, qy = [], []

    # SUPPORT → BOTH domains
    for i in s_idx:
        img, l, d = dataset[i]

        if l in classes:
            sx.append(img)
            sy.append(cmap[l])
            sd.append(d)

    # QUERY → ONLY PlantVillage (domain=1)
    for i in q_idx:
        img, l, d = dataset[i]

        if l in classes and d == 1:
            qx.append(img)
            qy.append(cmap[l])

    if len(sx) == 0 or len(qx) == 0:
        return None

    return (
        torch.stack(sx),
        torch.tensor(sy),
        torch.tensor(sd),
        torch.stack(qx),
        torch.tensor(qy)
    )

# %%
acc_list = []
f1_list = []
train_acc_list = []
all_preds = []
all_labels = []

for ep,(s_idx,q_idx,cls) in enumerate(sampler):

    data = create_episode_reverse(combined_dataset, s_idx, q_idx, cls)

    if data is None:
        continue

    sx, sy, sd, qx, qy = data

    sx,sy,sd = sx.to(device),sy.to(device),sd.to(device)
    qx,qy = qx.to(device),qy.to(device)

    optimizer.zero_grad()

    with higher.innerloop_ctx(model, optimizer, copy_initial_weights=True) as (fmodel, diffopt):

        # -------- INNER LOOP --------
        sf = F.normalize(fmodel(sx), dim=1)

        loss1 = contrastive_loss(sf, sy)

        proto = compute_prototypes(sf, sy, len(cls))
        logits = -euclidean_dist(sf, proto)

        loss2 = F.cross_entropy(logits, sy)

        diffopt.step(loss1 + loss2)

        # TRAIN ACC
        train_pred = logits.argmax(1)
        train_acc = (train_pred == sy).float().mean().item()

        # -------- OUTER LOOP --------
        qf = F.normalize(fmodel(qx), dim=1)

        with torch.no_grad():
            sf_adapted = F.normalize(fmodel(sx), dim=1)

        proto = compute_prototypes(sf_adapted, sy, len(cls))
        logits = -euclidean_dist(qf, proto)

        loss_outer = F.cross_entropy(logits, qy)

        loss_dom = domain_loss(sf_adapted, sy, sd, len(cls))

        loss = loss_outer + 0.1 * loss_dom

        loss.backward()

        # TEST ACC
        test_pred = logits.argmax(1)
        test_acc = (test_pred == qy).float().mean().item()

    torch.nn.utils.clip_grad_norm_(model.parameters(),1.0)
    optimizer.step()

    pred = logits.argmax(1)

    acc = (pred==qy).float().mean().item()
    f1 = f1_score(qy.cpu(),pred.cpu(),average="macro")

    acc_list.append(acc)
    f1_list.append(f1)

    # ✅ ADD HERE
    train_acc_list.append(train_acc)
    all_preds.extend(pred.cpu().numpy())
    all_labels.extend(qy.cpu().numpy())

    if ep % 50 == 0:
        print(f"Ep {ep} | Train Acc {train_acc:.3f} | Test Acc {test_acc:.3f} | F1 {f1:.3f}")


print("\nFINAL RESULTS")
print("Mean Train Accuracy:", np.mean(train_acc_list))
print("Mean Test Accuracy:", np.mean(acc_list))
print("Mean F1:", np.mean(f1_list))
# Out:
# Ep 0 | Train Acc 1.000 | Test Acc 0.800 | F1 0.800
# Ep 50 | Train Acc 1.000 | Test Acc 0.854 | F1 0.856
# Ep 100 | Train Acc 0.960 | Test Acc 0.625 | F1 0.630
# Ep 150 | Train Acc 1.000 | Test Acc 0.681 | F1 0.660
# Ep 200 | Train Acc 0.960 | Test Acc 0.816 | F1 0.821
# Ep 250 | Train Acc 1.000 | Test Acc 0.540 | F1 0.533
# Ep 300 | Train Acc 1.000 | Test Acc 0.735 | F1 0.740
# Ep 350 | Train Acc 1.000 | Test Acc 0.592 | F1 0.597
# Ep 400 | Train Acc 1.000 | Test Acc 0.733 | F1 0.717
# Ep 450 | Train Acc 1.000 | Test Acc 0.917 | F1 0.916
# Ep 500 | Train Acc 1.000 | Test Acc 0.766 | F1 0.769
# Ep 550 | Train Acc 1.000 | Test Acc 0.771 | F1 0.759
# Ep 600 | Train Acc 1.000 | Test Acc 0.773 | F1 0.769
# Ep 650 | Train Acc 1.000 | Test Acc 0.717 | F1 0.707
# Ep 700 | Train Acc 1.000 | Test Acc 0.583 | F1 0.568
# Ep 750 | Train Acc 1.000 | Test Acc 0.714 | F1 0.724
# Ep 800 | Train Acc 1.000 | Test Acc 0.714 | F1 0.714
# Ep 850 | Train Acc 1.000 | Test Acc 0.592 | F1 0.591
# Ep 900 | Train Acc 1.000 | Test Acc 0.787 | F1 0.782
# Ep 950 | Train Acc 1.000 | Test Acc 0.755 | F1 0.747
#
# FINAL RESULTS
# Mean Train Accuracy: 0.9990399994850159
# Mean Test Accuracy: 0.7107378927171231
# Mean F1: 0.7095237056267303

# %%
import matplotlib.pyplot as plt

plt.plot(acc_list, label="Test Accuracy")
plt.xlabel("Episodes")
plt.ylabel("Accuracy")
plt.title("Test Accuracy over Episodes")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(all_labels, all_preds)

sns.heatmap(cm, annot=False, cmap="Blues")
plt.title("Confusion Matrix")
plt.show()
